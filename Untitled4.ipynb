# %%
import om
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\agile\AppData\Local\Programs\Python\Python37\lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\agile\AppData\Local\Temp\ipykernel_9672\1085829849.py", line 1, in <module>
#     import om
#
#   File "D:\backend\python\om.py", line 2
#     print "prakash"
#         ^
# IndentationError: expected an indented block

# %%
import one
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\agile\AppData\Local\Programs\Python\Python37\lib\site-packages\IPython\core\interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\agile\AppData\Local\Temp\ipykernel_9672\3976538692.py", line 1, in <module>
#     import one
#
#   File "D:\backend\python\one.py", line 2
#     a =10
#     ^
# IndentationError: expected an indented block
